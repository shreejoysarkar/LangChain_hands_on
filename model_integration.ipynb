# %% [markdown]
# ## HuggingFace model

# %%
from langchain_ollama import ChatOllama
model = ChatOllama(model = 'llama3.1')

# %%
# !ollama list
# Out:
# NAME                        ID              SIZE      MODIFIED
# llama3.1:latest             46e0c10c039e    4.9 GB    8 days ago
# embeddinggemma:latest       85462619ee72    621 MB    9 days ago
# mxbai-embed-large:latest    468836162de7    669 MB    9 days ago
# gemma:2b                    b50d6c999e59    1.7 GB    11 days ago

# %%
response = model.invoke("how do parrots talk")
response.content
# Out:
# "Parrot vocalizations are a fascinating topic, and I'd be happy to explain how they produce their remarkable talking abilities.\n\n**Anatomy of the Parrot's Vocal Apparatus**\n\nTo understand how parrots talk, we need to look at the anatomy of their vocal apparatus. A parrot's syrinx is located at the base of the trachea, unlike humans who have a larynx (voice box) in the throat. The syrinx is a complex organ that consists of two pairs of cartilaginous rings that vibrate when air passes through them, producing sound waves.\n\n**Unique Features of Parrot Syrinx**\n\nThe parrot's syrinx has several unique features that allow for an impressive range of vocalizations:\n\n1. **Diversity of Sound-Generating Mechanisms**: Unlike humans, who rely on a single pair of vocal cords, parrots have two pairs of cartilaginous rings in their syrinx. This allows them to produce a wide range of sounds, from simple chirps and whistles to complex words and phrases.\n2. **Advanced Syringeal Musculature**:
# ...

# %%
## Streaming the output 

for chunk in model.stream("why do parrots talk"):
    print(chunk.text)
# Out:
# Par
# rots
#  are
#  known
#  for
#  their
#  remarkable
#  ability
#  to
#  mimic
#  human
#  speech
#  and
#  other
#  sounds
#  they
#  hear
#  in
#  their
#  environment
# .
#  There
#  are
#  several
#  reasons
#  why
#  par
# rots
#  talk
# :
#
#
# 1
# .
#  **
# Ev
# olution
# ary
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 ## Streaming the output
# ----> 3 for chunk in model.stream("why do parrots talk"):
#       4     print(chunk.text)
#
# File d:\LangChain_hands_on\Langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:540, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     538 index = -1
#     539 index_type = ""
# --> 540 for chunk in self._stream(input_messages, stop=stop, **kwargs):
#     541     if chunk.message.id is None:
#     542         chunk.message.id = run_id
#
# ...

# %%
## batch : a collection of independent requests to a model can significantly improve performance 
##         and reduce costs, as the processing can be done in parallel

responses = model.batch([
    "Why do parrots have colorfull feathers?",
    "how do airplanes fly?",
    "who is michael jordon"
])

for response in responses:
    print(response)
# Out:
# content="Parrots' colorful feathers are a remarkable feature that has evolved over millions of years. Here's why they have such vibrant plumage:\n\n**Evolutionary advantages:**\n\n1. **Mating and courtship**: Bright colors serve as an indicator of a parrot's health, fitness, and genetic quality. Males with more vibrant plumage may be perceived as stronger competitors for mates.\n2. **Territorial signaling**: Colorful feathers help parrots establish dominance over their territory by warning other birds to stay away.\n3. **Warning signals**: Bright colors can also signal to potential predators that a parrot is distasteful or toxic, serving as an anti-predator defense mechanism.\n\n**Physical and chemical factors:**\n\n1. **Melanin and carotenoids**: Parrots have high levels of melanin (the pigment responsible for black and brown colors) in their feathers, which interact with light to produce the vibrant hues we see.\n2. **Iridescent effects**: The microscopic structure of parrot feathe
# ...

# %%
responses = model.batch([
    "Why do parrots have colorfull feathers?",
    "how do airplanes fly?",
    "who is michael jordon",
    config = {
        "max_concurrency" : 5 ### Limit to 5 parallel calls
    }
])
