# %% [markdown]
# # how chatbot remembers chat history

# %%
import os

from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage
from langchain_core.messages import AIMessage
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
model = ChatOllama(
    model = 'llama3.1'
)

# %%
model.invoke([HumanMessage(content = "Hi, My name is shreejoy and I am an AI engineer ")])
# Out:
# AIMessage(content="Nice to meet you, Shreejoy! AI engineer, that's a cool field. What kind of AI projects have you been working on lately? Are you more into machine learning, natural language processing, or computer vision?", additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-03-11T18:01:10.8270533Z', 'done': True, 'done_reason': 'stop', 'total_duration': 21119288900, 'load_duration': 9201125600, 'prompt_eval_count': 25, 'prompt_eval_duration': 3201946700, 'eval_count': 46, 'eval_duration': 8652243900, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019cde0e-fb26-7411-bf40-fb4e21a6602a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 25, 'output_tokens': 46, 'total_tokens': 71})

# %%
model.invoke(
    [
        HumanMessage(content = "Hi, My name is shreejoy and I am an AI engineer"),
        AIMessage(content = "Nice to meet you, Shreejoy! That's a cool profession. AI engineering is a rapidly growing field, and I'm sure you're contributing to some exciting projects. What kind of AI-related work do you specialize in? Are you working on computer vision, natural language processing, or perhaps reinforcement learning?"),
        HumanMessage(content="Hey whats my name and what do i do?")
    ]
)
# Out:
# AIMessage(content="Your name is Shreejoy, and you're an AI engineer!", additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-03-11T18:01:21.0906893Z', 'done': True, 'done_reason': 'stop', 'total_duration': 10175753000, 'load_duration': 257042400, 'prompt_eval_count': 106, 'prompt_eval_duration': 7150378900, 'eval_count': 15, 'eval_duration': 2744261300, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019cde0f-4e01-7643-81c6-f18c4936af2d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 106, 'output_tokens': 15, 'total_tokens': 121})

# %%
## message history

store = {}
def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()

    return store[session_id]


with_message_history = RunnableWithMessageHistory(model , get_session_history)

# %%
config = {"configurable" : {"session_id":"chat1"}}

# %%
response = with_message_history.invoke(
    [HumanMessage (content = "Hi, My name is shreejoy and I am an AI engineer")],
    config  =config
)

# %%
response.content
# Out:
# 'Nice to meet you, Shreejoy! Welcome to our conversation!\n\nAI engineering is a fascinating field. What specific areas of AI are you working on or interested in, such as computer vision, natural language processing, reinforcement learning, or something else?'

# %%
with_message_history.invoke(
    [HumanMessage (content = "Hi, My name is shreejoy and I am an AI engineer")],
    config  =config
)
# Out:
# AIMessage(content="It looks like you already introduced yourself! I'll play along, though.\n\nSo, Shreejoy the AI engineer, what brings you here today? Are you looking for advice, seeking to learn from others, or just wanting to chat about the latest developments in AI?", additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-03-11T18:01:43.3943208Z', 'done': True, 'done_reason': 'stop', 'total_duration': 12131983900, 'load_duration': 152213000, 'prompt_eval_count': 98, 'prompt_eval_duration': 2051994200, 'eval_count': 55, 'eval_duration': 9891286000, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019cde0f-9d7c-7fb1-847b-3363d633e87e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 98, 'output_tokens': 55, 'total_tokens': 153})

# %%
config1 = {"configurable" : {"session_id":"chat2"}}

response= with_message_history.invoke(
    [HumanMessage(content='Whats my name?')],
    config = config1
)

# %%
response.content
# Out:
# "I'm a large language model, I don't have any information about your personal details, including your name. This is our first conversation, and I don't retain any information about individual users. Would you like to introduce yourself?"

# %% [markdown]
# # Prompt Template

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpfull assistant . Answer all the question to the best of your ability",),
        MessagesPlaceholder(variable_name= "messages")
    ]
)

chain = prompt|model

# %%
chain.invoke({"messages":[HumanMessage(content = "hi my name is krish")]})
# Out:
# AIMessage(content="Hello Krish! It's nice to meet you. Is there something I can help you with today?", additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-03-11T18:01:58.9069571Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6611777500, 'load_duration': 197113600, 'prompt_eval_count': 38, 'prompt_eval_duration': 2751698400, 'eval_count': 21, 'eval_duration': 3639857400, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019cde0f-efa6-7763-a80f-e1776f8479b7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 38, 'output_tokens': 21, 'total_tokens': 59})

# %%
with_message_history = RunnableWithMessageHistory(chain, get_session_history)

# %%
config = {"configurable":{"session_id" : "chat3"}}

response = with_message_history.invoke(
    [HumanMessage(content = "hi my name is krish")]
)
